# %%
from statistics import mean

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL.ImageOps import scale
from matplotlib import rcParams
rcParams['font.sans-serif'] = ['STHeiti']
rcParams['axes.unicode_minus'] = False

penguins = pd.read_csv('../../data/penguins.csv')
penguins.dropna(inplace=True)
penguins.info()
penguins.head()
# Out:
# <class 'pandas.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    str
#  1   island             333 non-null    str
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 20.8 KB
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# 直方图 (hist, Histogram)
sns.histplot(data=penguins, x='bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
# 核密度估计图 (KDE, Kernel Density Estimation)
# 曲线面积积分严格等于 1
sns.kdeplot(data=penguins, x='bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', kde=True)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', hue='species', kde=True)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
# 计数图
"""
计数图 与 直方图 的区别：
计数图 统计的是离散量，一根柱子代表一个值
直方图 统计的是连续量，一根柱子代表某一个区间的统计数量
"""
sns.countplot(data=penguins, x='island')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
# 散点图
sns.scatterplot(data=penguins, x='body_mass_g', y='bill_length_mm', hue='sex', size='bill_depth_mm')
# 调用 matplotlib 中的方法把图例放在图外
plt.legend(bbox_to_anchor=(1.05, 0.5), loc='center left', borderaxespad=0, prop={'size': 14})

# %%
# 蜂窝图
sns.jointplot(data=penguins, x='body_mass_g', y='flipper_length_mm', kind='hex')

# %%
# 二维 KDE
# sns.kdeplot(data=penguins, x='body_mass_g')
sns.kdeplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', fill=True, cmap='viridis')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# 散点图和二维KDE结合
sns.kdeplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', fill=True, cmap='viridis')
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', alpha=0.5)
plt.show()

# %%
# 条形图
sns.barplot(data=penguins, x='species', y='body_mass_g', estimator='mean', errorbar=None)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# 箱线图
sns.boxplot(data=penguins, x='species', y='bill_length_mm')
plt.show()

# %%
# 小提琴图
sns.violinplot(data=penguins, x='species', y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# 成对关系图
sns.pairplot(data=penguins, hue='species')
