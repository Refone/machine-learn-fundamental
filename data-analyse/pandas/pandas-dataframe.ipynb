# %%
# dataframe 创建
import pandas as pd
import numpy as np

s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series(['a', 'b', 'c', 'd', 'e'])
df = pd.DataFrame({"第一列":s2, '第二列':s1})
df
# Out:
#   第一列  第二列
# 0   a    1
# 1   b    2
# 2   c    3
# 3   d    4
# 4   e    5

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
type(df['第一列'])
# Out:
# pandas.Series

# %%
df = pd.DataFrame(
    {
        "name":['Tom', 'Jack', 'Alice', 'Bob', 'Charlie'],
        'age':[15, 17, 20, 26, 30],
        'score':[60.5, 80, 30.6, 70, 83.5]
    }, index= [1, 2, 3, 4, 5],
    columns=['name', 'age', 'score']
)
df
# Out:
#       name  age  score
# 1      Tom   15   60.5
# 2     Jack   17   80.0
# 3    Alice   20   30.6
# 4      Bob   26   70.0
# 5  Charlie   30   83.5

# %%
print('行索引')
df.index
# Out:
# 行索引
# Index([1, 2, 3, 4, 5], dtype='int64')

# %%
df.columns # 列标签
# Out:
# Index(['name', 'age', 'score'], dtype='str')

# %%
df.values # 值
# Out:
# array([['Tom', 15, 60.5],
#        ['Jack', 17, 80.0],
#        ['Alice', 20, 30.6],
#        ['Bob', 26, 70.0],
#        ['Charlie', 30, 83.5]], dtype=object)

# %%
df.ndim # 维度
# Out:
# 2

# %%
df.dtypes # 类型
# Out:
# name         str
# age        int64
# score    float64
# dtype: object

# %%
df.shape # 形状
# Out:
# (5, 3)

# %%
df.size # 元素个数
# Out:
# 15

# %%
df.T # 转置
# Out:
#           1     2      3     4        5
# name    Tom  Jack  Alice   Bob  Charlie
# age      15    17     20    26       30
# score  60.5  80.0   30.6  70.0     83.5

# %%
df.T.columns
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64')

# %%
df.T.index
# Out:
# Index(['name', 'age', 'score'], dtype='str')

# %%
df
# Out:
#       name  age  score
# 1      Tom   15   60.5
# 2     Jack   17   80.0
# 3    Alice   20   30.6
# 4      Bob   26   70.0
# 5  Charlie   30   83.5

# %%
df.loc[4]
# Out:
# name      Bob
# age        26
# score    70.0
# Name: 4, dtype: object

# %%
df.iloc[3]
# Out:
# name      Bob
# age        26
# score    70.0
# Name: 4, dtype: object

# %%
df.loc[:,'name']
# Out:
# 1        Tom
# 2       Jack
# 3      Alice
# 4        Bob
# 5    Charlie
# Name: name, dtype: str

# %%
df.loc[:2,:]
# Out:
#    name  age  score
# 1   Tom   15   60.5
# 2  Jack   17   80.0

# %%
df
# Out:
#       name  age  score
# 1      Tom   15   60.5
# 2     Jack   17   80.0
# 3    Alice   20   30.6
# 4      Bob   26   70.0
# 5  Charlie   30   83.5

# %%
df.at[3, 'score']
# Out:
# np.float64(30.6)

# %%
df.iat[2, 1]
# Out:
# np.int64(20)

# %%
df['name']
# Out:
# 1        Tom
# 2       Jack
# 3      Alice
# 4        Bob
# 5    Charlie
# Name: name, dtype: str

# %%
df.name
# Out:
# 1        Tom
# 2       Jack
# 3      Alice
# 4        Bob
# 5    Charlie
# Name: name, dtype: str

# %%
# 查看部分数据
print(df.head(3))
# Out:
#     name  age  score
# 1    Tom   15   60.5
# 2   Jack   17   80.0
# 3  Alice   20   30.6

# %%
df.tail(2)
# Out:
#       name  age  score
# 4      Bob   26   70.0
# 5  Charlie   30   83.5

# %%
df
# Out:
#       name  age  score
# 1      Tom   15   60.5
# 2     Jack   17   80.0
# 3    Alice   20   30.6
# 4      Bob   26   70.0
# 5  Charlie   30   83.5

# %%
df[df.score>70]
# Out:
#       name  age  score
# 2     Jack   17   80.0
# 5  Charlie   30   83.5

# %%
df[(df.score>70) & (df.age<20)]
# Out:
#    name  age  score
# 2  Jack   17   80.0

# %%
# 随机抽样
df.sample(4)
# Out:
#       name  age  score
# 4      Bob   26   70.0
# 3    Alice   20   30.6
# 2     Jack   17   80.0
# 5  Charlie   30   83.5

# %%
df.isin(['Jack', 20])
# Out:
#     name    age  score
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False
# 4  False  False  False
# 5  False  False  False

# %%
df.sum()
# Out:
# name     TomJackAliceBobCharlie
# age                         108
# score                     324.6
# dtype: object

# %%
df['score'].sum().round(1)
# Out:
# np.float64(324.6)

# %%
df.score.max()
# Out:
# np.float64(83.5)

# %%
df.age.min()
# Out:
# np.int64(15)

# %%
df.score.mean()
# Out:
# np.float64(64.92)

# %%
df.score.median()
# Out:
# np.float64(70.0)

# %%
df.describe().round(1)
# Out:
#         age  score
# count   5.0    5.0
# mean   21.6   64.9
# std     6.3   21.2
# min    15.0   30.6
# 25%    17.0   60.5
# 50%    20.0   70.0
# 75%    26.0   80.0
# max    30.0   83.5

# %%
df = pd.DataFrame(
    {
        "name":['Tom', 'Jack', 'Alice', 'Bob', 'Charlie', 'Bob'],
        'age':[15, 17, 20, 26, 30, 26],
        'score':[60.5, 80, 30.6, 70, 83.5, 70]
    }, index= [1, 2, 3, 4, 5, 6],
    columns=['name', 'age', 'score']
)
print(df.value_counts()) #出现次数
# Out:
# name     age  score
# Bob      26   70.0     2
# Tom      15   60.5     1
# Jack     17   80.0     1
# Alice    20   30.6     1
# Charlie  30   83.5     1
# Name: count, dtype: int64

# %%
df.sample(2)
# Out:
#       name  age  score
# 5  Charlie   30   83.5
# 2     Jack   17   80.0

# %%
df.replace(15, 30)
# Out:
#       name  age  score
# 1      Tom   30   60.5
# 2     Jack   17   80.0
# 3    Alice   20   30.6
# 4      Bob   26   70.0
# 5  Charlie   30   83.5
# 6      Bob   26   70.0

# %%
df
# Out:
#       name  age  score
# 1      Tom   15   60.5
# 2     Jack   17   80.0
# 3    Alice   20   30.6
# 4      Bob   26   70.0
# 5  Charlie   30   83.5
# 6      Bob   26   70.0

# %%
df.cumsum()
df.cummin()
# Out:
#     name  age  score
# 1    Tom   15   60.5
# 2   Jack   15   60.5
# 3  Alice   15   30.6
# 4  Alice   15   30.6
# 5  Alice   15   30.6
# 6  Alice   15   30.6

# %%
print(df.sort_index(ascending=False))
# Out:
#       name  age  score
# 6      Bob   26   70.0
# 5  Charlie   30   83.5
# 4      Bob   26   70.0
# 3    Alice   20   30.6
# 2     Jack   17   80.0
# 1      Tom   15   60.5

# %%
df.sort_values(by=['age','score'], ascending=[False,True])
# Out:
#       name  age  score
# 5  Charlie   30   83.5
# 4      Bob   26   70.0
# 6      Bob   26   70.0
# 3    Alice   20   30.6
# 2     Jack   17   80.0
# 1      Tom   15   60.5

# %%
df.nlargest(2, columns=['score', 'age'])
# Out:
#       name  age  score
# 5  Charlie   30   83.5
# 2     Jack   17   80.0
